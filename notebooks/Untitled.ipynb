# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
print("Setup complete!")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Setup complete!

# %% [markdown]
# ### Шаг 2. Исследовательский анализ

# %%
data_2019 = pd.read_csv('../data/2019.csv')
data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# #### 2.1 Корреляционная матрица

# %%
data_without_obj = data_2019.drop(columns=['Country or region'])
correlation_matrix = data_without_obj.corr()
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### 2.2 Построение графика для всех пар числовых признаков

# %%
sns.pairplot(data_2019)

# %% [markdown]
# #### 2.3 Построение графиков для поиска связей между признаками

# %%
sns.regplot(x=data_2019['GDP per capita'], y=data_2019['Score'])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Score'>

# %%
sns.regplot(x=data_2019['Healthy life expectancy'], y=data_2019['Score'])
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Score'>

# %%
sns.regplot(x=data_2019['Freedom to make life choices'], y=data_2019['Score'])
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Score'>

# %%
sns.regplot(x=data_2019['Score'], y=data_2019['Perceptions of corruption'])
# Out:
# <Axes: xlabel='Score', ylabel='Perceptions of corruption'>

# %%
sns.regplot(x=data_2019['GDP per capita'], y=data_2019['Perceptions of corruption'])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Perceptions of corruption'>

# %%
sns.regplot(x=data_2019['GDP per capita'], y=data_2019['Generosity'])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Generosity'>

# %%
sns.regplot(x=data_2019['GDP per capita'], y=data_2019['Healthy life expectancy'])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Healthy life expectancy'>
